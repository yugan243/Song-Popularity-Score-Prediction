# %% [markdown]
# # Feature Engineering

# %% [markdown]
# This notebook is used for creating new features from the existing ones

# %% [markdown]
# ## 1. Setting up the Environment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2. Load Data

# %%
import sys
sys.path.append('..')


from src.data.load_data import load_data


train_df, test_df = load_data(train_path='../data/processed/train_processed.csv',
                              test_path='../data/processed/test_processed.csv')
# Out:
# Loading training data from ../data/processed/train_processed.csv
# Loading test data from ../data/processed/test_processed.csv
# Train shape: (61609, 62)
# Test shape: (41074, 61)

# %% [markdown]
# ## 3. Derive New Features from 'Publication_Timestamp'

# %%
from src.data.build_features import create_date_features_train_test

train_df, test_df = create_date_features_train_test(train_df, test_df, date_col='publication_timestamp', target_col='target')

# %%
train_df.drop('publication_timestamp', axis=1, inplace=True)
test_df.drop('publication_timestamp', axis=1, inplace=True)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61609 entries, 0 to 61608
# Data columns (total 82 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  61609 non-null  float64
#  1   emotional_charge_2                  61609 non-null  float64
#  2   groove_efficiency_1                 61609 non-null  float64
#  3   beat_frequency_1                    61609 non-null  float64
#  4   organic_texture_2                   61609 non-null  float64
#  5   composition_label_0                 61609 non-null  object
#  6   harmonic_scale_1                    61609 non-null  float64
#  7   intensity_index_0                   61609 non-null  float64
#  8   duration_ms_0                       61609 non-null  float64
#  9   album_name_length                   61609 non-null  float64
#  10  beat_frequency_0                    61609 non-null  float64
#  11  beat_frequency_2                    61609 non-null  float64
#  12  artist_count                        61609 non-null  float64
#  13  composition_label_1                 61609 non-null  object
#  14  weekday_of_release                  61609 non-null  object
#  15  album_component_count               61609 non-null  float64
#  16  emotional_charge_1                  61609 non-null  float64
#  17  emotional_charge_0                  61609 non-null  float64
#  18  tonal_mode_2                        61609 non-null  float64
#  19  key_variety                         61609 non-null  float64
#  20  performance_authenticity_2          61609 non-null  float64
#  21  performance_authenticity_0          61609 non-null  float64
#  22  season_of_release                   61609 non-null  object
#  23  time_signature_1                    61609 non-null  float64
#  24  duration_ms_2                       61609 non-null  float64
#  25  lunar_phase                         61609 non-null  object
#  26  instrumental_density_2              61609 non-null  float64
#  27  organic_texture_0                   61609 non-null  float64
#  28  creator_collective                  61609 non-null  object
#  29  vocal_presence_2                    61609 non-null  float64
#  30  tonal_mode_1                        61609 non-null  float64
#  31  vocal_presence_1                    61609 non-null  float64
#  32  vocal_presence_0                    61609 non-null  float64
#  33  intensity_index_1                   61609 non-null  float64
#  34  organic_immersion_0                 61609 non-null  float64
#  35  tonal_mode_0                        61609 non-null  float64
#  36  groove_efficiency_2                 61609 non-null  float64
#  37  instrumental_density_1              61609 non-null  float64
#  38  organic_immersion_2                 61609 non-null  float64
#  39  duration_consistency                61609 non-null  float64
#  40  composition_label_2                 61609 non-null  object
#  41  organic_texture_1                   61609 non-null  float64
#  42  rhythmic_cohesion_0                 61609 non-null  float64
#  43  track_identifier                    61609 non-null  object
#  44  emotional_resonance_1               61609 non-null  float64
#  45  rhythmic_cohesion_1                 61609 non-null  float64
#  46  performance_authenticity_1          61609 non-null  float64
#  47  tempo_volatility                    61609 non-null  float64
#  48  organic_immersion_1                 61609 non-null  float64
#  49  groove_efficiency_0                 61609 non-null  float64
#  50  emotional_resonance_2               61609 non-null  float64
#  51  time_signature_0                    61609 non-null  float64
#  52  duration_ms_1                       61609 non-null  float64
#  53  harmonic_scale_0                    61609 non-null  float64
#  54  time_signature_2                    61609 non-null  float64
#  55  rhythmic_cohesion_2                 61609 non-null  float64
#  56  emotional_resonance_0               61609 non-null  float64
#  57  harmonic_scale_2                    61609 non-null  float64
#  58  intensity_index_2                   61609 non-null  float64
#  59  instrumental_density_0              61609 non-null  float64
#  60  target                              61609 non-null  int64
#  61  release_year                        61609 non-null  int32
#  62  release_month                       61609 non-null  int32
#  63  release_day                         61609 non-null  int32
#  64  release_dayofweek                   61609 non-null  int32
#  65  release_quarter                     61609 non-null  int32
#  66  week_of_year                        61609 non-null  int64
#  67  day_of_year                         61609 non-null  int32
#  68  is_weekend_release                  61609 non-null  int64
#  69  is_summer_release                   61609 non-null  int64
#  70  is_end_of_year                      61609 non-null  int64
#  71  is_valentines_week                  61609 non-null  int64
#  72  is_new_year_release                 61609 non-null  int64
#  73  month_sin                           61609 non-null  float64
#  74  month_cos                           61609 non-null  float64
#  75  day_sin                             61609 non-null  float64
#  76  day_cos                             61609 non-null  float64
#  77  songs_released_that_year            61609 non-null  int64
#  78  songs_released_that_month           61609 non-null  int64
#  79  release_period_in_month             61609 non-null  category
#  80  release_month_popularity_score      61609 non-null  float64
#  81  release_dayofweek_popularity_score  61609 non-null  float64
# dtypes: category(1), float64(58), int32(6), int64(9), object(8)
# memory usage: 36.7+ MB

# %%
train_df.head()
# Out:
#         id  emotional_charge_2  groove_efficiency_1  beat_frequency_1  \
# 0  76339.0            0.482850             1.169231            80.018
# 1  80006.0            0.267862             1.321321           147.966
# 2  83501.0            0.242606             1.285319           142.980
# 3  81530.0            0.426400             1.279435           123.063
# 4  60534.0            0.000000             0.974906           132.722
#
#    organic_texture_2              composition_label_0  harmonic_scale_1  \
# 0             0.0201  Country Stuff (feat. Jake Owen)               1.0
# 1             0.3340                         Solitude               6.0
# 2             0.1110  BDFFRNT (Saved from Conformity)               4.0
# 3             0.1960         Headlights (feat. Ilsey)               5.0
# 4             0.0811                           Afraid               6.0
#
#    intensity_index_0  duration_ms_0  album_name_length  ...  \
# 0             0.7890       154586.0               13.8  ...
# 1             0.7150        46874.0               15.0  ...
# 2             0.7288       264665.0                7.0  ...
# 3             0.6850       209208.0                5.0  ...
# 4             0.8560       215346.0                5.0  ...
#
#    is_new_year_release     month_sin     month_cos   day_sin   day_cos  \
# 0                    0  1.224647e-16 -1.000000e+00  0.724793  0.688967
# 1                    0 -5.000000e-01 -8.660254e-01  0.201299  0.979530
# 2                    0 -5.000000e-01  8.660254e-01 -0.485302 -0.874347
# 3                    0 -1.000000e+00 -1.836970e-16 -0.937752  0.347305
# 4                    1  5.000000e-01  8.660254e-01  0.201299  0.979530
#
#    songs_released_that_year  songs_released_that_month  \
# 0                     11679                       1413
# 1                      6104                        426
# 2                      2071                        212
# 3                      2757                        289
# 4                       718                        300
#
#    release_period_in_month  release_month_popularity_score  \
# 0                    early                       53.437764
# 1                    early                       49.497283
# 2                      mid                       54.297864
# 3                     late                       52.833078
# 4                    early                       49.883403
#
#    release_dayofweek_popularity_score
# 0                           56.875643
# 1                           48.965015
# 2                           50.665790
# 3                           56.875643
# 4                           44.805190
#
# [5 rows x 82 columns]

# %%
train_df.to_csv('../data/processed/train_new1.csv', index=False)
test_df.to_csv('../data/processed/test_new1.csv', index=False)

# %% [markdown]
# ## 4. Create features from Highly Correlated Features

# %%
import sys
sys.path.append('..')

from src.data.load_data import load_data
from src.data.build_features import create_composition_features


train_df, test_df = load_data(train_path="../data/processed/train_encoded.csv",
                              test_path="../data/processed/test_encoded.csv"
                              )
train_df, test_df = create_composition_features(train_df, test_df, n_clusters=5)
# Out:
# Loading training data from ../data/processed/train_encoded.csv
# Loading test data from ../data/processed/test_encoded.csv
# Train shape: (61609, 97)
# Test shape: (41074, 96)

# %%
from src.utils.utils import save_dataframe, load_config
import os

# Save the encoded data
config = load_config('../configs/config.yaml')
processed_dir = config['data']['processed_dir']

train_save_path = os.path.join(processed_dir, "train_encoded.csv")
test_save_path = os.path.join(processed_dir, "test_encoded.csv")

save_dataframe(train_df, train_save_path)
save_dataframe(test_df, test_save_path)

print("[INFO] Encoded datasets saved successfully.")
# Out:
# [INFO] DataFrame saved to ../data/processed\train_encoded.csv
# [INFO] DataFrame saved to ../data/processed\test_encoded.csv
# [INFO] Encoded datasets saved successfully.
